# %% [markdown]
# ### Mineral and financial research of iodine
#
# Goal: survey and collect information about the iodine as a mineral commodity.
# Questions:
# - What is its valuation and capacity? Does its value fluctuate?
# - What are the approximate untapped sources of it, eg ppm coastal briny waters?
# - How much biomass is required to harvest 1 unit of iodine per day?
# - How much does extraction cost, roughly?
# - Who are the buyers and sellers?
# - What are the policy and environmental regulations?
# Basically, do the numbers add up, and what does it take to make the financials balance?

# %% [markdown]
# [Decent exchange resource for viewing commodities](https://tradingeconomics.com/commodities)

# %% [markdown]
# {
#     AI google response to search: "industrial commodity price index"
#
#
#     Industrial commodity pricing reflects the fluctuating costs of raw materials (metals, energy, agricultural goods) driven by supply/demand, economic growth, and policy, tracked via indices like the BLS Producer Price Index (PPI) or World Bank data, impacting production costs and signaling broader inflation trends for businesses and economists. Key factors influencing these prices include energy costs, global demand, supply chain issues, and currency fluctuations, with recent trends showing overall easing prices but volatility in specific sectors like metals. [1, 2, 3, 4, 5, 6]
# Key Indicators & Data Sources
#
# • BLS Producer Price Index (PPI): Measures average changes in selling prices received by domestic producers for their output, a key gauge of inflation.
# • World Bank Commodity Markets: Provides global price indices for energy, metals, food, and raw materials, with forecasts.
# • Trading Economics: Offers live commodity prices (e.g., metals, agricultural goods) and forecasts.
# • FRED (Federal Reserve Economic Data): Hosts various indices, including the Global Price of Industrial Materials index. [1, 2, 3, 7, 8, 9, 10, 11]
#
# Factors Influencing Prices
#
# • Supply & Demand: Basic economic principle; high demand and low supply drive prices up.
# • Economic Growth: Strong global growth boosts demand for industrial materials, while slowdowns decrease it.
# • Energy Costs: Oil, natural gas, and coal significantly impact production and transport costs for other commodities.
# • Policy & Geopolitics: Trade policies, geopolitical events, and central bank actions can disrupt supply chains and prices.
# • Currency Exchange Rates: Affect the cost of globally traded commodities. [3, 4, 5, 6, 8]
#
# How It's Used
#
# • For Businesses: To understand input costs, forecast future expenses, and inform pricing strategies (e.g., value-based pricing).
# • For Economists & Investors: As leading indicators for inflation (PPI) and economic health, influencing monetary policy decisions and investment strategies. [2, 3, 4, 11, 12]
#
# Current Trends (as of late 2025/early 2026)
#
# • Global commodity prices are generally projected to fall, reaching multi-year lows due to weak growth and surplus.
# • Energy and food indices have shown recent easing, though metals like copper and nickel have seen price increases. [3, 6]
#
# AI responses may include mistakes.
#
# [1] https://ycharts.com/indicators/us_producer_price_index_industrial_commodities
# [2] https://www.bls.gov/ppi/
# [3] https://www.worldbank.org/en/research/commodity-markets
# [4] https://www.bluwave.net/industrial-manufacturing-pricing/
# [5] https://gunvorgroup.com/glossary/commodity-price/
# [6] https://www.youtube.com/watch?v=K0t_0yhHUqc
# [7] https://fred.stlouisfed.org/series/WPU1144
# [8] https://tradingeconomics.com/commodities
# [9] https://tradingeconomics.com/commodity/gsci
# [10] https://fred.stlouisfed.org/series/PINDUINDEXM
# [11] https://www.moomoo.com/us/learn/detail-ppi-producer-price-index-117460-240929107
# [12] https://www.investopedia.com/articles/economics/11/breaking-down-producers-price-index.asp
#
#
# }

# %% [markdown]
# more sources, from iodine wikipedia
#
# wiki:
# 0.46 parts per million in earth's crust.
# Chilean caliche: In total, they can contain at least 0.02% and at most 1% iodine by mass.
#
# Greenwood NN, Earnshaw A (1997). Chemistry of the Elements (2nd ed.). Butterworth-Heinemann. p. 28. doi:10.1016/C2009-0-30414-6. ISBN 978-0-08-037941-8  <- frequently cited.
# pp. 795–796: "Chile and Japan are the largest producers of iodine today"
#
# Kogel JE, Trivedi NC, Barker JM, Krukowski ST, eds. (2006). Industrial Minerals & Rocks: Commodities, Markets, and Uses. SME. pp. 541–552. ISBN 978-0-87335-233-8.  https://books.google.com/books?id=zNicdkuulE4C. alt citation: Jessica Elzea Kogel; Nikhil C. Trivedi; James M. Barker; Stanley T. Krukowski (2006). Industrial Minerals & Rocks: Commodities, Markets, and Uses. SME. pp. 541–552. ISBN 978-0-87335-233-8.
#
# Stanford EC (1862). "On the Economic Applications of Seaweed". Journal of the Society of Arts: 185–189.  https://books.google.com/books?id=wW8KAAAAIAAJ&pg=PA185
#
# Maekawa T, Igari SI, Kaneko N (2006). "Chemical and isotopic compositions of brines from dissolved-in-water type natural gas fields in Chiba, Japan". Geochemical Journal. 40 (5): 475. Bibcode:2006GeocJ..40..475M. doi:10.2343/geochemj.40.475.  https://doi.org/10.2343%2Fgeochemj.40.475
#
# industrial mineral commodities:
# https://pubs.usgs.gov/periodicals/mcs2024/mcs2024.pdf
# ^ excellent.

# %% [markdown]
# US Geological Survey, Mineral Commodities Summary, 2024, excerpts.
#
# Prepared by Emily K. Schnebele [(703) 648–4945, eschnebele@usgs.gov]
#
# IODINE
#
# (Data in metric tons, elemental iodine, unless otherwise specified)
#
# Domestic Production and Use: Iodine was produced from brines in 2023 by three companies operating in
# Oklahoma. U.S. iodine production in 2023 was withheld to avoid disclosing company proprietary data but was
# estimated to have decreased from that in 2022. The annual average cost, insurance, and freight unit value of iodine
# imports in 2023 was estimated to be $61 per kilogram, about 30% more than that in 2022.
#
# Because domestic and imported iodine was used by downstream manufacturers to produce many intermediate iodine
# compounds, it was difficult to establish an accurate end-use pattern. Crude iodine and inorganic iodine compounds
# were thought to account for more than 50% of domestic iodine consumption in 2023. Worldwide, the leading uses of
# iodine and its compounds were X-ray contrast media (XRCM), pharmaceuticals, liquid crystal displays (LCDs),
# iodophors, animal feed, and fluorochemicals, in descending order of quantity consumed. Other applications of iodine
# included biocides, food supplements, and nylon.
#
# | Salient Statistics—United States: | 2019 | 2020 | 2021 | 2022 | 2023e|
#
# | Production | W | W | W | W | W |
#
# | Imports for consumption | 4,300 | 4,570 | 4,120 | 4,270 | 3,600|
#
# | Exports | 1,230 | 1,130 | 1,280 | 1,140 | 1,300|
#
# Consumption:
# Apparent1 W W W W W
# | Reported | 4,000 | 3,750 | 3,720 | 3,330 | 3,000|
# | Price, crude iodine, average unit value of imports (cost, insurance,
# and freight), dollars per kilogram | 26.38 | 31.57 | 32.72 | 45.81|  61|
# | Employment, number e | 60 | 60 | 60 | 60 | 60|
# | Net import reliance 2 as a percentage of apparent consumption | >50 | >50 | >50 | >50 | >50|
# Recycling: Small amounts of iodine were recycled.
# Import Sources (2019–22): Chile, 89%; Japan, 10%; and other, 1%.
# Tariff: Item Number Normal Trade Relations
# 12–31–23
# Iodine, crude 2801.20.0000 Free.
# Depletion Allowance: 14% (domestic and foreign).
# Government Stockpile: None.
#
# Events, Trends, and Issues: According to industry publications, spot prices for iodine crystal averaged about $73 per kilogram during the first 8 months of 2023. This was about 5% more than the 2022 annual average of $69.11 per kilogram. Iodine price increases were attributed to strong global demand and limited supply.
#
# World mine production and reserves: Reserves data for Iran were revised based on Government reports. China also produces crude iodine, but output was not officially reported, and available information was inadequate to make reliable estimates of output. Available information was inadequate to make an estimate of iodine reserves in Indonesia for 2022.
# Mine productione 2022, Mine production 2023,  Reserves3
# United States W W 250,000
# Azerbaijan 170 200 170,000
# Chile 19,200 19,000 610,000
# Indonesia  29 30 NA
# Iran 700 700 40,000
# Japan 9,200 9,000 4,900,000
# Russia 3 3 120,000
# Turkmenistan 770 800 70,000
# World total (rounded) 30,100 30,000 6,200,000
#
# World Resources: 3 Seawater contains 0.06 part per million iodine, and the oceans are estimated to contain approximately 90 billion tons of iodine. Seaweeds of the Laminaria family are able to extract and accumulate up to 0.45% iodine on a dry basis. Although not as economical as the production of iodine as a byproduct of gas, nitrates, and oil, the seaweed industry represented a major source of iodine prior to 1959 and remains a large resource.
#
# Substitutes: No comparable substitutes exist for iodine in many of its principal applications, such as in animal feed, catalytic, nutritional, pharmaceutical, and photographic uses. Bromine and chlorine could be substituted for iodine in biocide, colorant, and ink, although they are usually considered less desirable than iodine. Antibiotics can be used as a substitute for iodine biocides.

# %%
# Back-of-envelope calculations
'''
    0.06*1e-6 ppm iodine in seawater
    0.0045g iodine per g seaweed = 1g iodine per 222g kelp
    $70 per kg iodine = $0.07 per g iodine

       $.07      g iodine
    --------- x  -------- = $ .0003 per g kelp or 30 cents per kg kelp
     g iodine    222g kelp

     **AI**: Biomass (Tons per Acre): Surveys have shown natural bull kelp beds in 
     Northern California ranging from approximately 4.8 to 28 tons per acre, 
     depending on the year and specific location. Peak abundances of up to 200 tons 
     per acre have been recorded in the past in some specific coves.

     20 tons per acre x 907.2 kg/ton = 18144 kg
     $.30 /kg  x  18144 kg/acre = $5443.20/acre gross iodine value

     1 acre = 4047 square meter. If we estimate we could engineer a microorganism could grow 1 kg per 1 square meters, we'd have rougly 4000kg per acre.
     0400kg is 22% the stated natural kelp biomass yield.
     => would yield $1200/acre, or about $.30/square meter (sanity checked).

     How fast does brown seaweed Laminaria grow?
     - **UPDATE**: https://en.wikipedia.org/wiki/Laminaria_digitata  This has the info I'm looking for. See a later cell
     - Laminaria grows large:  7 meters
     - Laminaria live on the order of handfuls of years, 3-20, median 4
     => Roughly estimate, 1.5 meter per year or 20% of its peak biomass per year.
     - Species: Laminaria digitata (Oarweed), Laminaria hyperborea (Cuvie/Tangle).
     Of note: they thrive in cold water.

     Roughly estimate that:
     - we could reengineer a microorganism that grows in 10% of the time of kelp
     - in a dense mat panned near the sun that can rival kelp biomass per area,
     - with sufficient iodine-containing water running over it to let it reach peak iodine capacity easily
     - and we can engineer higher specificity by 240% increase to guarantee $1 iodine per kg.

       $0.3      1 kg kelp    10 unit time kelp growth        240  iodine density
      ------  x  --------  x  -----------------------      x  ---  in microorg
      kg kelp    sq meter     1 unit time microorg growth     100  vs. kelp
    
      = $3 per square meter (per year?)

'''
0.0045**-1
.07/222.22
20*907.2
18144*.3
18.144**-1*4 * 5443
1200/4000.
.003**-1
# Out:
# 333.3333333333333

# %% [markdown]
# "Microalgae can grow 20 or 30 times faster than traditional food crops, and has no need to compete for arable land." https://en.wikipedia.org/wiki/Culture_of_microalgae_in_hatcheries.
# - [reference 1] Greenwell, HC; Laurens, LML; Shields, RJ; Lovitt, RW; Flynn, KJ (2010). "[Placing microalgae on the biofuels priority list: a review of the technological challenges](http://rsif.royalsocietypublishing.org/content/7/46/703.full)". J. R. Soc. Interface. 7 (46): 703–726. doi:10.1098/rsif.2009.0322. PMC 2874236. PMID 20031983.
# - [reference 2] McDill, Stuart (2009-02-10). "[Can algae save the world – again?](https://www.reuters.com/article/environmentNews/idUSTRE5196HB20090210?pageNumber=2&virtualBrandChannel=0)". Reuters. Retrieved 2009-02-10.
#
# ----
#
# https://en.wikipedia.org/wiki/Laminaria_digitata
# Laminaria digitata is found mostly on exposed sites on shores in the lower littoral where it may form extensive meadows and can be the dominant algal species. It has a fairly high intrinsic growth rate compared to other algae, 5.5% per day, and a carrying capacity of about 40 kg wet weight per square meter. It may reach lengths of about 4 m (13 ft). It overlaps to a small degree in distribution with Fucus serratus and Alaria esculenta. It is highly susceptible to grazing by sea urchins, among other species. It has low and high light limitation values of about 5 and 70 W per square meter respectively. Its distribution is also limited by salinity, wave exposure, temperature, desiccation and general stress. These and other attributes of the alga are summarized in the publications listed below.[4][5][6]
#
# 4,5,6:
# - Lewis, J.R. (1964). The Ecology of Rocky Shores. English Universities Press, London.
# - Seip, K.L. 1980. A mathematical model of competition and colonization in a community of marine benthic algae. Ecological modelling 10:77-104
# - Seip, K.L. Mathematical models of rocky shore ecosystems. In Jørgensen, SE and Mitch, WJ (Eds) Application of ecological modelling in environmental management, Part B, Chap 13, pp 341-433
#
# ----

# %%
'''
These numbers are far from exact 
5.5%/day x 19 days = full growth
40 kgs / m^2 => expect 2 kg/m^2
which amounts to 20-100 g iodine per day per m^2, post-processing. 
    (1-5% iodine by weight comes from something I saw today, within 
     web-browsing-infodumps.md::<jan-27-workcomp>)
Now, what is the usual turnover rate of microalgae that can hold up to say 0.2%-12% iodine by weight?

also, to calculate mineral dry weight vs wet weight, look at web-browsing-infodumps.md::[tag377562])
  but that's not a tonight task...

'''
0.055**-1
# Out:
# 18.181818181818183

# %% [markdown]
# Note: a brief survey of other similar minerals recoverable recoverable from seawater aquaculture (namely, Mg2+, Br-, and other widespread ions) indicate that indeed iodine is best for being limited in viable sources, commodity value per unit mass, uniquely crucial for industry and healthcare, and already recognized and used by organisms (vs. say Apixaban)
#
# Alternative. Naphtha is roughly 500 USD/T = $.50 /kg.
#
# Other aside: Calcium is important for industrial applications. Marine autotroph protists Coccolithophorids love it for their shells and are important ecologically for carbon capture.

# %% [markdown]
# #### next: calculate raw quantities of iodine available, and match worldwide consumption?

# %% [markdown]
# https://www.youtube.com/watch?v=2hf9yN-oBV4
# I grew real spider silk using yeast, the thought emporium
#
# "
# 22:07
# species of yeast called Pishia Pastorus...And it's also fantastic at producing huge quantities of proteins and so is actually used
# industrially to produce things like insulin. We're talking gram per liter quantities here, which might not sound
# like a lot, but keep in mind that at scale, growing thousands of lers of yeast is really quite easy. Just look at
# the beer industry. Vegemite is only a thing because of the hundreds of kilograms of yeast left over from
# brewing beer.
# 22:50
#
# (inter-excerpt)
# ...Pishia itself is actually a really interesting species. It can eat methanol and the plasmid actually has a methanol trigger built in. So will only produce silk when given that trigger. It can also survive in quite high salinity, well past ocean salinity. And it's also fantastic ...
# "

# %% [markdown]
# 5.27.2026. According to Algal Biorefineries Vol 1, Bajpai & Prokop & Zappi, 2014, 3.2 page 79, the potential high growth rate of [freshwater] algae is 20 g/m^2 /day.  Lots of good info in this chapter about basic numbers for growth! e.g. CO2(aq) is preferred, HCO3- is okay, but CO3(2-) under basic conditions is unusable in algae. Also, 40% of cost is CO2 and 30% of greenhouse gas emissions come from CO2, so industrial waste CO2 is a very ripe opportunity.
#
# Compare this to above calculations for kelp:
# 4.8-28 tons per acre per year
#   x 1/4047 square meters per acre
#   x 907185 grams per ton
#   x 1/365 days per year
#
# In [2]: 1./4047 * 907185 / 365  *4.8
# Out[2]: 2.9478883394092024
#
# In [3]: 1./4047 * 907185 / 365  *28
# Out[3]: 17.196015313220347
#
# = 3-17 grams per day per square meter, which is roughly the same number.

# %% [markdown]
# ### SQM report analysis
#
# According to a 2019 SQM report, they "use caliche to produce salts rich in nitrates and iodine, through heap [or vat] leaching and the use of solar evaporation ponds". at one site, using approx. 400x200 ft of ponds, and 2000x5000ft at another, and 3000x3500ft roughly, approx 1 square mile, and these facilities are shared across other productions (nitrates, lithium, potassium, borates).  (Estimated by looking at google maps of their main evaporation facilities).
#
# Proven/probable caliche reserves owned by SQM: 550, 1900 million metric tons; iodine at 300-400 parts per million
#
# Our total iodine production in 2019 was 12,082 metric tons: 9,558 metric tons from Nueva Victoria, 1,174 metric tons from Iris, and 1,351 metric tons from Pedro de Valdivia....  Our current potassium nitrate production capacity at Coya Sur is approximately 1,300,000 metric tons per year.... generated approximately 700,000 tons of inventory [of sodium nitrate].... [Approved to] mine up to 37 million metric tons of caliche per year.... 1-1.2 million tons nitrate per year....Production capacity for the potassium sulfate plant is approximately 340,000 metric tons per year.
#
# Nueva Victoria, (in thousands, unless otherwise stated). 2019, 2018, 2017:
# Metric tons of ore mined :  42196, 42753, 36383 (in thousands, unless otherwise stated)
# Metric tons of iodine produced :  10.7 10.2 8.8 (in thousands, unless otherwise stated)
# Matches iodine yield; 300ppm = .0003; yield at roughly .00024 is 80%.
#
# In [3]: 550*1e6/(42196*1e3)
# Out[3]: 13.034410844629823
#
# In [4]: 1900*1e6/(42196*1e3)
# Out[4]: 45.02796473599393
#
# They have 20 years of reserves.
#
# ---
#
# an essential processing step is 'prilling' (pelletizing) minerals, and shipped as such?
#
# ----
#
#
# They sell their iodine at roughly 25USD/kg.
# I: 126, O: 16, K: 39.
#
# In [1]: 126 / (126+3*16+39)
# Out[1]: 0.5915492957746479
#
# In [2]: 25/80.
# Out[2]: 0.3125
#
# In [3]: 25/0.5915
# Out[3]: 42.26542688
#
# Hmm.
#
# ---
#
#
# Stated risk factors:
# New production of iodine, potassium nitrate or lithium from current or new competitors in the markets in which we operate could adversely affect prices
#
# In recent years, new and existing competitors have increased the supply of iodine, potassium nitrate and lithium, which has affected prices for those products. Further production increases could negatively impact prices. There is limited information on the status of new iodine, potassium nitrate or lithium production capacity expansion projects being developed by current and potential competitors and, as such, we cannot make accurate projections regarding the capacities of possible new entrants into the market and the dates on which they could become operational. If these potential projects are completed in the short term, they could adversely affect market prices and our market share, which, in turn, could have a material adverse effect on our business, financial condition and results of operations.
#
# risk factors continued.
# "Our reserves estimates are internally prepared and not subject to review by external geologists or an external auditing firm and could be subject to significant changes, which may have a material adverse effect on our business, financial condition and results of operations"
# "A significant percentage of our shares are held by two principal shareholder groups who may have interests that are different from that of other shareholders and of each other."
# "As we are a company based in Chile, we are exposed to Chilean political risks ... We are exposed to economic and political volatility and civil unrest in Chile."
# "Ratification of the International Labor Organization’s Convention 169 concerning indigenous and tribal peoples might affect our development plans"
#
#
# (aux/Memoria-Anual-2019_eng_final.pdf)
#
#
# ---
#
# "On January 13, 2017, as part of an investigation by the U.S. Securities and Exchange Commission into violations of the Foreign Corrupt Practices Act, SQM agreed to pay a USD30 million penalty to resolve parallel civil and criminal cases.[25] According to the investigation, the company made $15 million in improper payments to Chilean political figures and others connected to them in a seven-year period." (wikipedia)
#
# ---
#
#
# Iodine - Wikipedia
# https://en.wikipedia.org/wiki/Iodine#Occurrence_and_production
#
# Caliche - Wikipedia
# https://en.wikipedia.org/wiki/Caliche
#
# Paradas method - Wikipedia
# https://en.wikipedia.org/wiki/Paradas_method
#
# Sociedad Química y Minera - Wikipedia
# https://en.wikipedia.org/wiki/Sociedad_Qu%C3%ADmica_y_Minera
#
# Coquina - Wikipedia
# https://en.wikipedia.org/wiki/Coquina
#
# San-miguel-island-caliche.jpg (JPEG Image, 800 × 593 pixels)
# https://upload.wikimedia.org/wikipedia/commons/5/51/San-miguel-island-caliche.jpg
#
# Soil horizon - Wikipedia
# https://en.wikipedia.org/wiki/Soil_horizon#A_horizon
#
# Antofagasta Region - Wikipedia
# https://en.wikipedia.org/wiki/Antofagasta_Region
#
# Salar de Atacama - Wikipedia
# https://en.wikipedia.org/wiki/Salar_de_Atacama
#
# American depositary receipt - Wikipedia
# https://en.wikipedia.org/wiki/American_depositary_receipt
